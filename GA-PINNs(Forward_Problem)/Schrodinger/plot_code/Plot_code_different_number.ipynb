# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False,
                 "font.family"   : "Times New Roman", "font.scale": 1.5}

sns.set_style(style="ticks", rc=custom_params)

# %% [markdown]
# # J_6

# %%
test_loss_2 = np.load('../experimental_data/J_6/test_loss_2.npy')
test_loss_3 = np.load('../experimental_data/J_6/test_loss_3.npy')
test_loss_4 = np.load('../experimental_data/J_6/test_loss_4.npy')

# %%
times = 800
x_max = 15000

x2_index = np.arange(0,len(test_loss_2),times)
x3_index = np.arange(0,len(test_loss_3),times)
x4_index = np.arange(0,len(test_loss_4),times)

x2_index = np.concatenate((x2_index,[len(test_loss_2)-1]),axis=0)
x3_index = np.concatenate((x3_index,[len(test_loss_3)-1]),axis=0)
x4_index = np.concatenate((x4_index,[len(test_loss_4)-1]),axis=0)

plt.figure(figsize=(8,4))

sns.lineplot(x=x2_index+1,y=test_loss_2[x2_index],label = 'GA-PINN',c='b', marker="s", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x3_index+1,y=test_loss_3[x3_index],label = 'PINN$^{\dag}$',c='orange', marker="^", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x4_index+1,y=test_loss_4[x4_index],label = 'GA-PINN$ ^{\dag}$',c='r', marker="o", markersize=7, markeredgecolor="white", markeredgewidth=1.2)

plt.xlabel('Iteration',fontsize=20)
plt.ylabel('NRMSE',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend(loc='upper right', frameon=False, fontsize=20, ncol=1)

for spine in plt.gca().spines.values():
    spine.set_edgecolor("#CCCCCC")
    spine.set_linewidth(1.5)
    
plt.yscale('log')

plt.savefig('../figures/Schrodinger_NRMSE_J_6.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # J_7

# %%
test_loss_2 = np.load('../experimental_data/J_7/test_loss_2.npy')
test_loss_3 = np.load('../experimental_data/J_7/test_loss_3.npy')
test_loss_4 = np.load('../experimental_data/J_7/test_loss_4.npy')

# %%
times = 800
x_max = 15000

x2_index = np.arange(0,len(test_loss_2),times)
x3_index = np.arange(0,len(test_loss_3),times)
x4_index = np.arange(0,len(test_loss_4),times)

x2_index = np.concatenate((x2_index,[len(test_loss_2)-1]),axis=0)
x3_index = np.concatenate((x3_index,[len(test_loss_3)-1]),axis=0)
x4_index = np.concatenate((x4_index,[len(test_loss_4)-1]),axis=0)

plt.figure(figsize=(8,4))

sns.lineplot(x=x2_index+1,y=test_loss_2[x2_index],label = 'GA-PINN',c='b', marker="s", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x3_index+1,y=test_loss_3[x3_index],label = 'PINN$^{\dag}$',c='orange', marker="^", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x4_index+1,y=test_loss_4[x4_index],label = 'GA-PINN$ ^{\dag}$',c='r', marker="o", markersize=7, markeredgecolor="white", markeredgewidth=1.2)

plt.xlabel('Iteration',fontsize=20)
plt.ylabel('NRMSE',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend(loc='upper right', frameon=False, fontsize=20, ncol=1)

for spine in plt.gca().spines.values():
    spine.set_edgecolor("#CCCCCC")
    spine.set_linewidth(1.5)
    
plt.yscale('log') 

plt.savefig('../figures/Schrodinger_NRMSE_J_7.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # J_8

# %%
test_loss_2 = np.load('../experimental_data/J_8/test_loss_2.npy')
test_loss_3 = np.load('../experimental_data/J_8/test_loss_3.npy')
test_loss_4 = np.load('../experimental_data/J_8/test_loss_4.npy')

# %%
times = 800
x_max = 15000

x2_index = np.arange(0,len(test_loss_2),times)
x3_index = np.arange(0,len(test_loss_3),times)
x4_index = np.arange(0,len(test_loss_4),times)

x2_index = np.concatenate((x2_index,[len(test_loss_2)-1]),axis=0)
x3_index = np.concatenate((x3_index,[len(test_loss_3)-1]),axis=0)
x4_index = np.concatenate((x4_index,[len(test_loss_4)-1]),axis=0)

plt.figure(figsize=(8,4))

sns.lineplot(x=x2_index+1,y=test_loss_2[x2_index],label = 'GA-PINN',c='b', marker="s", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x3_index+1,y=test_loss_3[x3_index],label = 'PINN$^{\dag}$',c='orange', marker="^", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x4_index+1,y=test_loss_4[x4_index],label = 'GA-PINN$ ^{\dag}$',c='r', marker="o", markersize=7, markeredgecolor="white", markeredgewidth=1.2)

plt.xlabel('Iteration',fontsize=20)
plt.ylabel('NRMSE',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend(loc='upper right', frameon=False, fontsize=20, ncol=1)

for spine in plt.gca().spines.values():
    spine.set_edgecolor("#CCCCCC")
    spine.set_linewidth(1.5)
    
plt.yscale('log')

plt.savefig('../figures/Schrodinger_NRMSE_J_8.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # J_9

# %%
test_loss_2 = np.load('../experimental_data/J_9/test_loss_2.npy')
test_loss_3 = np.load('../experimental_data/J_9/test_loss_3.npy')
test_loss_4 = np.load('../experimental_data/J_9/test_loss_4.npy')

# %%
times = 836
x_max = 15000


x2_index = np.arange(0,len(test_loss_2),times)
x3_index = np.arange(0,len(test_loss_3),times)
x4_index = np.arange(0,len(test_loss_4),times)

x2_index = np.concatenate((x2_index,[len(test_loss_2)-1]),axis=0)
x3_index = np.concatenate((x3_index,[len(test_loss_3)-1]),axis=0)
x4_index = np.concatenate((x4_index,[len(test_loss_4)-1]),axis=0)

plt.figure(figsize=(8,4))

sns.lineplot(x=x2_index+1,y=test_loss_2[x2_index],label = 'GA-PINN',c='b', marker="s", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x3_index+1,y=test_loss_3[x3_index],label = 'PINN$^{\dag}$',c='orange', marker="^", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x4_index+1,y=test_loss_4[x4_index],label = 'GA-PINN$ ^{\dag}$',c='r', marker="o", markersize=7, markeredgecolor="white", markeredgewidth=1.2)

plt.xlabel('Iteration',fontsize=20)
plt.ylabel('NRMSE',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend(loc='upper right', frameon=False, fontsize=20, ncol=1)

for spine in plt.gca().spines.values():
    spine.set_edgecolor("#CCCCCC")
    spine.set_linewidth(1.5)

plt.yscale('log')

plt.savefig('../figures/Schrodinger_NRMSE_J_9.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # J_11

# %%
test_loss_2 = np.load('../experimental_data/J_11/test_loss_2.npy')
test_loss_3 = np.load('../experimental_data/J_11/test_loss_3.npy')
test_loss_4 = np.load('../experimental_data/J_11/test_loss_4.npy')

# %%
times = 802
x_max = 15000

x2_index = np.arange(0,len(test_loss_2),times)
x3_index = np.arange(0,len(test_loss_3),times)
x4_index = np.arange(0,len(test_loss_4),times)

x2_index = np.concatenate((x2_index,[len(test_loss_2)-1]),axis=0)
x3_index = np.concatenate((x3_index,[len(test_loss_3)-1]),axis=0)
x4_index = np.concatenate((x4_index,[len(test_loss_4)-1]),axis=0)

plt.figure(figsize=(8,4))

sns.lineplot(x=x2_index+1,y=test_loss_2[x2_index],label = 'GA-PINN',c='b', marker="s", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x3_index+1,y=test_loss_3[x3_index],label = 'PINN$^{\dag}$',c='orange', marker="^", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x4_index+1,y=test_loss_4[x4_index],label = 'GA-PINN$ ^{\dag}$',c='r', marker="o", markersize=7, markeredgecolor="white", markeredgewidth=1.2)

plt.xlabel('Iteration',fontsize=20)
plt.ylabel('NRMSE',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend(loc='upper right', frameon=False, fontsize=20, ncol=1)

for spine in plt.gca().spines.values():
    spine.set_edgecolor("#CCCCCC")
    spine.set_linewidth(1.5)
    
plt.yscale('log') 

plt.savefig('../figures/Schrodinger_NRMSE_J_11.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # J_12

# %%
test_loss_2 = np.load('../experimental_data/J_12/test_loss_2.npy')
test_loss_3 = np.load('../experimental_data/J_12/test_loss_3.npy')
test_loss_4 = np.load('../experimental_data/J_12/test_loss_4.npy')

# %%
times = 891
x_max = 15000

x2_index = np.arange(0,len(test_loss_2),times)
x3_index = np.arange(0,len(test_loss_3),times)
x4_index = np.arange(0,len(test_loss_4),times)

x2_index = np.concatenate((x2_index,[len(test_loss_2)-1]),axis=0)
x3_index = np.concatenate((x3_index,[len(test_loss_3)-1]),axis=0)
x4_index = np.concatenate((x4_index,[len(test_loss_4)-1]),axis=0)

plt.figure(figsize=(8,4))

sns.lineplot(x=x2_index+1,y=test_loss_2[x2_index],label = 'GA-PINN',c='b', marker="s", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x3_index+1,y=test_loss_3[x3_index],label = 'PINN$^{\dag}$',c='orange', marker="^", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x4_index+1,y=test_loss_4[x4_index],label = 'GA-PINN$ ^{\dag}$',c='r', marker="o", markersize=7, markeredgecolor="white", markeredgewidth=1.2)

plt.xlabel('Iteration',fontsize=20)
plt.ylabel('NRMSE',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.legend(loc='upper right', frameon=False, fontsize=20, ncol=1)

for spine in plt.gca().spines.values():
    spine.set_edgecolor("#CCCCCC")
    spine.set_linewidth(1.5)
    
plt.yscale('log') 

plt.savefig('../figures/Schrodinger_NRMSE_J_12.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped
