# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

# %%
custom_params = {"axes.spines.right": False, "axes.spines.top": False,
                 "font.family"   : "Times New Roman", "font.scale": 1.5}

sns.set_style(style="ticks", rc=custom_params)

# %% [markdown]
# # HD-Poisson

# %%
test_loss_1 = np.load('../experimental_data/method_1/test_loss_1.npy')
test_loss_2 = np.load('../experimental_data/method_2/test_loss_2.npy')
test_loss_3 = np.load('../experimental_data/method_3/test_loss_3.npy')
test_loss_4 = np.load('../experimental_data/method_4/test_loss_4.npy')
test_loss_5 = np.load('../experimental_data/method_5/test_loss_5.npy')

loss_all_1 = np.load('../experimental_data/method_1/loss_all_1.npy')
loss_all_2 = np.load('../experimental_data/method_2/loss_all_2.npy')
loss_all_3 = np.load('../experimental_data/method_3/loss_all_3.npy')
loss_all_4 = np.load('../experimental_data/method_4/loss_all_4.npy')
loss_all_5 = np.load('../experimental_data/method_5/loss_all_5.npy')



test_loss_1 = np.array(test_loss_1) 
test_loss_2 = np.array(test_loss_2) 
test_loss_3 = np.array(test_loss_3) 
test_loss_4 = np.array(test_loss_4) 
test_loss_5 = np.array(test_loss_5) 
loss_all_1 = np.array(loss_all_1) 
loss_all_2 = np.array(loss_all_2) 
loss_all_3 = np.array(loss_all_3) 
loss_all_4 = np.array(loss_all_4) 
loss_all_5 = np.array(loss_all_5)

# %%
print('e1:',test_loss_1[-1],'e2:',test_loss_2[-1],'e3:',test_loss_3[-1],'e4:',test_loss_4[-1],'e5:',test_loss_5[-1])
# Out:
# e1: 0.04369699044998096 e2: 0.04638042949875319 e3: 0.04168218982712318 e4: 0.04387293022520309 e5: 0.04332113077869941

# %%
x1 = np.arange(len(test_loss_1))+1
x2 = np.arange(len(test_loss_2))+1
x3 = np.arange(len(test_loss_3))+1
x4 = np.arange(len(test_loss_4))+1
x5 = np.arange(len(test_loss_5))+1

print( '$\mathrm{PINN}$',len(test_loss_1),'$\mathrm{GA-PINN}$',len(test_loss_2),
      '$\mathrm { PINN }^{\dagger}$',len(test_loss_3),'$\mathrm { GA - PINN }^{\dagger}$',len(test_loss_4),'$\mathrm { GA - PINN* }$',
      len(test_loss_5))
# Out:
# $\mathrm{PINN}$ 2608 $\mathrm{GA-PINN}$ 4354 $\mathrm { PINN }^{\dagger}$ 3304 $\mathrm { GA - PINN }^{\dagger}$ 6408 $\mathrm { GA - PINN* }$ 6526

# %%
x1 = np.arange(len(test_loss_1))+1
x2 = np.arange(len(test_loss_2))+1
x3 = np.arange(len(test_loss_3))+1
x4 = np.arange(len(test_loss_4))+1
x5 = np.arange(len(test_loss_5))+1
times = 400


x1_index = np.arange(0,len(test_loss_1),times).astype('int')
x1_index = np.append(x1_index,len(test_loss_1)-1).astype('int')
x2_index = np.arange(0,len(test_loss_2),times).astype('int')
x2_index = np.append(x2_index,len(test_loss_2)-1).astype('int')
x3_index = np.arange(0,len(test_loss_3),times).astype('int')
x3_index = np.append(x3_index,len(test_loss_3)-1).astype('int')
x4_index = np.arange(0,len(test_loss_4),times).astype('int')
x4_index = np.append(x4_index,len(test_loss_4)-1).astype('int')
x5_index = np.arange(0,len(test_loss_5),times).astype('int')
x5_index = np.append(x5_index,len(test_loss_5)-1).astype('int')

# %%
plt.figure(figsize=(8,4))

sns.lineplot(x=x1_index+1,y=test_loss_1[x1_index],label = 'PINN',c='g', marker="d", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x2_index+1,y=test_loss_2[x2_index],label = 'GA-PINN',c='b', marker="s", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x3_index+1,y=test_loss_3[x3_index],label = 'PINN$^{\dag}$',c='orange', marker="^", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x4_index+1,y=test_loss_4[x4_index],label = 'GA-PINN$ ^{\dag}$',c='r', marker="o", markersize=7, markeredgecolor="white", markeredgewidth=1.2)
sns.lineplot(x=x5_index+1,y=test_loss_5[x5_index],label = 'GA-PINN$^{\ddag }$', marker=">", markersize=7, markeredgecolor="white", markeredgewidth=1.2)

plt.xlabel('Iteration',fontsize=20)
plt.ylabel('NRMSE',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)


plt.legend(loc='upper right', frameon=False, fontsize=18, ncol=2)

for spine in plt.gca().spines.values():
    spine.set_edgecolor("#CCCCCC")
    spine.set_linewidth(1.5)
    
plt.yscale('log') 

plt.savefig('../figures/HDPoisson_NRMSE.pdf', dpi=300, bbox_inches='tight', format='pdf')
plt.show()
# Out:
# meta NOT subset; don't know how to subset; dropped
